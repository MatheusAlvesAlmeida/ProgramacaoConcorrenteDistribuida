# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

# %%
read_file = pd.read_csv("pc0.txt")
read_file.to_csv("/home/gabriel/Documents/CIn/PCD/ProgramacaoConcorrenteDistribuida/08/src/pc0.csv")

# %%
df = pd.read_csv('pc0.csv')['569'].values.tolist()
df2 = pd.read_csv('pc1.csv')['972'].values.tolist()
df3 = pd.read_csv('pc5.csv')['225'].values.tolist()
df4 = pd.read_csv('pc10.csv')['318'].values.tolist()
df5 = pd.read_csv('pc100.csv')['724'].values.tolist()
df6 = pd.read_csv('pc1000.csv')['789'].values.tolist()
df7 = pd.read_csv('pc10000.csv')['562'].values.tolist()

# %%
#average of all values of df
avg = sum(df)/len(df)
avg2 = sum(df2)/len(df2)
avg3 = sum(df3)/len(df3)
avg4 = sum(df4)/len(df4)
avg5 = sum(df5)/len(df5)
avg6 = sum(df6)/len(df6)
avg7 = sum(df7)/len(df7)

# %%
#standard deviation of all values of df
std = np.std(df)
std2 = np.std(df2)
std3 = np.std(df3)
std4 = np.std(df4)
std5 = np.std(df5)
std6 = np.std(df6)
std7 = np.std(df7)

# %%
#plot the bar code graph with the average and standard deviation
plt.bar(0, avg, align='center', capsize=10)
plt.bar(1, avg2, align='center', capsize=10)
plt.bar(2, avg3, align='center', capsize=10)
plt.bar(3, avg4, align='center', capsize=10)
plt.bar(4, avg5, align='center', capsize=10)
plt.bar(5, avg6, align='center', capsize=10)
plt.bar(6, avg7, align='center', capsize=10)
plt.xticks([0,1,2,3,4,5,6], ['0', '1', '5', '10', '100', '1000', '10000'])
plt.ylabel('Tempo (ms)')
plt.title('Tempo de publicação')
# Out:
# Text(0.5, 1.0, 'Tempo de publicação')

# %%
plt.rcParams["figure.autolayout"] = True

# List of data points
data = df5

# Plot bar chart with data points
plt.bar(data, data)

# Display the plot
plt.saveFig('5096.jpg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [53], line 10
#       7 plt.bar(data, data)
#       9 # Display the plot
# ---> 10 plt.saveFig('5096.jpg')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'saveFig'
# /home/gabriel/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)
